# %% [markdown]
# <a href="https://colab.research.google.com/github/thesurojit/Ukraine-Russia_Conflict/blob/main/Ukraine_Russia_Conflict_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas_profiling as pp

# %%
df=pd.read_csv("UkraineConflict.csv")

# %%
df
# Out:
#      EVENT_ID_CNTY      EVENT_DATE  YEAR  TIME_PRECISION  \
# 0           ROU448     20-May-2019  2019               1
# 1          ROU1885   28-March-2022  2022               1
# 2          ROU1940    28-July-2022  2022               1
# 3          ROU1945    31-July-2022  2022               1
# 4          ROU1947  04-August-2022  2022               1
# ...            ...             ...   ...             ...
# 6099       UKR5859    08-June-2018  2018               1
# 6100       UKR5862    08-June-2018  2018               1
# 6101       UKR5866    08-June-2018  2018               1
# 6102       UKR5869    08-June-2018  2018               1
# 6103       UKR5828    08-June-2018  2018               1
#
#                DISORDER_TYPE                  EVENT_TYPE  \
# 0         Political violence  Violence against civilians
# 1     Strategic developments      Strategic developments
# 2             Demonstrations                    Protests
# ...

# %%
data = pd.DataFrame(df)

# %%
profile = pp.ProfileReport(data)
profile.to_file("Report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # New Section
